# %%
import random

# Setting the seed
random.seed(42)
print(random.randint(1, 100))  # Output: 82

# Setting the same seed again
random.seed(42)
print(random.randint(1, 100))  # Output: 82 (Guaranteed!)
# Out:
# 82
# 82

# %%
random.seed(42)
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))
print(random.randint(1,100))
# Out:
# 82
# 15
# 4
# 95
